# %%
# March 25 Agenda #
###################

# Pandas Series
# Pandas DataFrame - Using Numpy Dataset
# Pandas DataFrame - Using Dict
# Pandas DataFrame - Using CSV
# Walk-through on Pandas inbuilt Functions
# Pandas DataFrame - Using JSON
# Pandas - Cleaning Data

# %%
# pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
# Pandas series

# %%
df = pd.Series([1.0,3.0,5.0,7.0,9.0,11.0,13.0])

# %%
df
# Out:
# 0     1.0
# 1     3.0
# 2     5.0
# 3     7.0
# 4     9.0
# 5    11.0
# 6    13.0
# dtype: float64

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (7,)

# %%
df.head(2) #head used to display the first n number of observations default n = 5
# Out:
# 0    1.0
# 1    3.0
# dtype: float64

# %%
df.tail(2) #tail used to display the last n number of observations default n = 5
# Out:
# 5    11.0
# 6    13.0
# dtype: float64

# %%
# Pandas DataFrame - Using Numpy Dataset
data = np.arange(0,20).reshape(5,4)
df = pd.DataFrame(data,index=['Row1','Row2','Row3','Row4','Row5'],columns=["Column1","Column2","Column3","Column4"])

# %%
df
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7

# %%
df.tail(3)
# Out:
#       Column1  Column2  Column3  Column4
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df.loc['Row1'] # accessing the rows
# Out:
# Column1    0
# Column2    1
# Column3    2
# Column4    3
# Name: Row1, dtype: int32

# %%
type(df.loc['Row2'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df.loc['Row1'] # accessing the rows
# Out:
# Column1    0
# Column2    1
# Column3    2
# Column4    3
# Name: Row1, dtype: int32

# %%
df.loc[['Row1','Row2']]
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7

# %%
#df.iloc[start:end,start:end]
df.iloc[2:,2:]
# Out:
#       Column3  Column4
# Row3       10       11
# Row4       14       15
# Row5       18       19

# %%
df
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df[['Column2','Column3']]
# Out:
#       Column2  Column3
# Row1        1        2
# Row2        5        6
# Row3        9       10
# Row4       13       14
# Row5       17       18

# %%
df['Column2']
# Out:
# Row1     1
# Row2     5
# Row3     9
# Row4    13
# Row5    17
# Name: Column2, dtype: int32

# %%
# Pandas DataFrame - Using Dict

data={
    
    "calories":[420,380,390,400],
    "Duration":[50,40,45,48]
}

df = pd.DataFrame(data)
df
# Out:
#    calories  Duration
# 0       420        50
# 1       380        40
# 2       390        45
# 3       400        48

# %%
df.loc[2]
# Out:
# calories    390
# Duration     45
# Name: 2, dtype: int64

# %%
df['calories']
# Out:
# 0    420
# 1    380
# 2    390
# 3    400
# Name: calories, dtype: int64

# %%
# Pandas DataFrame - Using CSV
# DataPart Changes -- [3,4,5,6,7,8,9]
df = pd.read_csv("data/supermarket_sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200     80.22
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880   489.048
# ...

# %%
df.tail(6)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%    Total  \
# 994  Electronic accessories       60.95         1   3.0475  63.9975
# 995       Health and beauty       40.35         1   2.0175  42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.49
# 997      Food and beverages       31.84         1   1.5920   33.432
# 998      Home and lifestyle       65.82         1   3.2910   69.111
# 999     Fashion accessories       88.34         7  30.9190  649.299
#
#            Date   Time  Payment    cogs  gross margin percentage  \
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                       object
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.size
# Out:
# 17000

# %%
df.describe() # Only shows numerical features
# Out:
#         Unit price     Quantity       Tax 5%        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   307.58738
# std      26.494628     2.923431    11.708825   234.17651
# min      10.080000     1.000000     0.508500    10.17000
# 25%      32.875000     3.000000     5.924875   118.49750
# 50%      55.230000     5.000000    12.088000   241.76000
# 75%      77.935000     8.000000    22.445250   448.90500
# max      99.960000    10.000000    49.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.220360e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# ...

# %%
df.describe(include='O')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     650-98-6268      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#          Total        Date   Time  Payment
# count     1000        1000   1000     1000
# unique     990          89    506        3
# top     87.234  02-07-2019  19:48  Ewallet
# freq         2          20      7      345

# %%
df.describe(include='all')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     650-98-6268      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
# missing value info

df.isna().sum()

# There is no missing values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
# abcd.csv
import pandas as pd
data_new = pd.read_csv(r"data/abcd.csv")
#data_new.isna().sum()

# %%
data_new
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0            NaN      A     Yangon        Member  Female
# 1            NaN      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176    NaN     Yangon        Member    Male
# 4    373-73-7910      A        NaN        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
data_new.isna().sum()
# Out:
# Invoice ID                 2
# Branch                     2
# City                       2
# Customer type              1
# Gender                     1
# Product line               0
# Unit price                 2
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       1
# Time                       1
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data_new[['Branch','Gender']]
# Out:
#     Branch  Gender
# 0        A  Female
# 1        C  Female
# 2      NaN    Male
# 3      NaN    Male
# 4        A    Male
# ..     ...     ...
# 995      C    Male
# 996      B  Female
# 997      A    Male
# 998      A    Male
# 999      A  Female
#
# [1000 rows x 2 columns]

# %%
data_new
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0            NaN      A     Yangon        Member  Female
# 1            NaN      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176    NaN     Yangon        Member    Male
# 4    373-73-7910      A        NaN        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
#for deleting rows and columns we use function called 'drop'

#we have to specify the axis 
#Axis=0 for rows
#Axis=1 for columns

updateDF = data_new.drop('Gender',axis=1) #default value for axis is 0.

# %%
updateDF
# Out:
#       Invoice ID Branch       City Customer type            Product line  \
# 0            NaN      A     Yangon        Member       Health and beauty
# 1            NaN      C  Naypyitaw        Normal  Electronic accessories
# 2    631-41-3108    NaN     Yangon        Normal      Home and lifestyle
# 3    123-19-1176    NaN     Yangon        Member       Health and beauty
# 4    373-73-7910      A        NaN        Normal       Sports and travel
# ..           ...    ...        ...           ...                     ...
# 995  233-67-5758      C  Naypyitaw        Normal       Health and beauty
# 996  303-96-2227      B   Mandalay        Normal      Home and lifestyle
# 997  727-02-1313      A     Yangon        Member      Food and beverages
# 998  347-56-2442      A     Yangon        Normal      Home and lifestyle
# 999  849-09-3807      A     Yangon        Member     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total        Date   Time      Payment  \
# ...

# %%
del updateDF['Invoice ID']

# %%
updateDF
# Out:
#     Branch       City Customer type            Product line  Unit price  \
# 0        A     Yangon        Member       Health and beauty       74.69
# 1        C  Naypyitaw        Normal  Electronic accessories       15.28
# 2      NaN     Yangon        Normal      Home and lifestyle       46.33
# 3      NaN     Yangon        Member       Health and beauty       58.22
# 4        A        NaN        Normal       Sports and travel         NaN
# ..     ...        ...           ...                     ...         ...
# 995      C  Naypyitaw        Normal       Health and beauty       40.35
# 996      B   Mandalay        Normal      Home and lifestyle       97.38
# 997      A     Yangon        Member      Food and beverages       31.84
# 998      A     Yangon        Normal      Home and lifestyle       65.82
# 999      A     Yangon        Member     Fashion accessories       88.34
#
#      Quantity   Tax 5%     Total        Date   Time      Payment    cogs  \
# ...

# %%
data_new.drop(['Branch','City'],axis=1)

# %%
df = pd.read_json("data/data.json")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df = pd.read_csv('data/dirtydata.csv')

df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df["Calories"].fillna(130.0, inplace=True)

# %%
df = pd.read_csv('data/dirtydata.csv')

# %%
x = df['Calories'].mean()

# %%
df["Calories"].fillna(x, inplace=True)

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df = pd.read_csv('data/dirtydata.csv')

x= df['Calories'].median()

# %%
df['Calories'].fillna(x,inplace=True)

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df = pd.read_csv('data/dirtydata.csv')

# %%
df['Calories'].mode()[0]
# Out:
# 300.0

# %%
# abcd.csv
import pandas as pd
data_new = pd.read_csv(r"data/abcd.csv")

# %%
data_new.describe(include='O')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count           998    998     998           999     999                 1000
# unique          998      3       3             2       2                    6
# top     449-16-6770      A  Yangon        Member  Female  Fashion accessories
# freq              1    338     339           501     501                  178
#
#            Total        Date   Time  Payment
# count       1000         999    999     1000
# unique       990          89    505        3
# top     189.0945  02-07-2019  14:42  Ewallet
# freq           2          20      7      345

# %%
data_new['Gender'].mode()
# Out:
# 0    Female
# dtype: object

# %%
data_new['Gender'].unique()
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %%
data_new['Gender'].value_counts()
# Out:
# Female    501
# Male      498
# Name: Gender, dtype: int64

# %%
function1(path,fileName)

fileNameWithPath= path +"\\"+ fileName
fileName
if ext==".csv":
    pd.read_csv(fileNameWithPath)
if ext==".xlsx":
    pd.read_excel(fileNameWithPath)

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\dell pc\Desktop\data\dirtydata.csv')

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.loc[7,'Duration']
# Out:
# 450

# %%
# df['Duration'].mode()[0]

# %%
x = df['Duration'].mode()[0]

# %%
x
# Out:
# 60

# %%
df.loc[7,'Duration'] = x

# %%
df.loc[7]
# Out:
# Duration              60
# Date        '2020/12/08'
# Pulse                104
# Maxpulse             134
# Calories           253.3
# Name: 7, dtype: object

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
 df.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
for x in df.index:
    print("The Index is :", x)
    if df.loc[x,'Duration']> 60:
        print("The Value Greater than 60 is : ", df.loc[x,'Duration'])
        df.drop(x,inplace=True)
#     if df.loc[x,'Duration']== 60:
#         print(df.loc[x,'Duration'])
#         print("Value found is 60")
#         print("Changing the value from 60 to 50")
#         df.loc[x,'Duration']=50
#         print("The Updated Value :", df.loc[x,'Duration'])
    print("========= \n")
# Out:
# The Index is : 0
# ...
#
# The Index is : 1
# ...
#
# The Index is : 2
# ...
#
# The Index is : 3
# ...
#
# The Index is : 4
# ...
#
# The Index is : 5
# ...
#
# The Index is : 6
# ...
#
# The Index is : 7
# The Value Greater than 60 is :  450
# ...
#
# The Index is : 8
# ...
#
# The Index is : 9
# ...
#
# The Index is : 10
# ...
#
# The Index is : 11
# ...
#
# The Index is : 12
# ...
#
# The Index is : 13
# ...
#
# The Index is : 14
# ...
#
# The Index is : 15
# ...
#
# The Index is : 16
# ...
#
# The Index is : 17
# ...
#
# The Index is : 18
# ...
#
# The Index is : 19
# ...
#
# The Index is : 20
# ...
#
# The Index is : 21
# ...
#
# The Index is : 22
# ...
#
# The Index is : 23
# ...
#
# The Index is : 24
# ...
#
# The Index is : 25
# ...
#
# The Index is : 26
# ...
#
# The Index is : 27
# ...
#
# The Index is : 28
# ...
#
# The Index is : 29
# ...
#
# The Index is : 30
# ...
#
# The Index is : 31
# ...

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
for i in df.index:
    print("The index ",i)
    print(df.loc[i,'Duration'])
    if df.loc[i,'Duration'] == 60:
        df.loc[i,'Duration'] = 50
    print("-------------")
# Out:
# The index  0
# 60
# -------------
# The index  1
# 60
# -------------
# The index  2
# 60
# -------------
# The index  3
# 45
# -------------
# The index  4
# 45
# -------------
# The index  5
# 60
# -------------
# The index  6
# 60
# -------------
# The index  7
# 450
# -------------
# The index  8
# 30
# -------------
# The index  9
# 60
# -------------
# The index  10
# 60
# -------------
# The index  11
# 60
# -------------
# The index  12
# 60
# -------------
# The index  13
# 60
# -------------
# The index  14
# 60
# -------------
# The index  15
# 60
# -------------
# The index  16
# 60
# -------------
# The index  17
# 60
# -------------
# The index  18
# 45
# -------------
# The index  19
# 60
# -------------
# The index  20
# 45
# -------------
# The index  21
# 60
# -------------
# The index  22
# 45
# -------------
# The index  23
# 60
# -------------
# The index  24
# 45
# -------------
# The index  25
# 60
# -------------
# The index  26
# 60
# -------------
# ...

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
df.reset_index(inplace=True)

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\dell pc\Desktop\data\dirtydata.csv')
for x in df.index:
    print("The Index is :", x)
    if df.loc[x,'Duration']> 60:
        print("The Value Greater than 60 is : ", df.loc[x,'Duration'])
        df.drop(x,inplace=True)
    print("========= \n")
#df.reset_index(drop=True,inplace=True)
# Out:
# The Index is : 0
# ...
#
# The Index is : 1
# ...
#
# The Index is : 2
# ...
#
# The Index is : 3
# ...
#
# The Index is : 4
# ...
#
# The Index is : 5
# ...
#
# The Index is : 6
# ...
#
# The Index is : 7
# The Value Greater than 60 is :  450
# ...
#
# The Index is : 8
# ...
#
# The Index is : 9
# ...
#
# The Index is : 10
# ...
#
# The Index is : 11
# ...
#
# The Index is : 12
# ...
#
# The Index is : 13
# ...
#
# The Index is : 14
# ...
#
# The Index is : 15
# ...
#
# The Index is : 16
# ...
#
# The Index is : 17
# ...
#
# The Index is : 18
# ...
#
# The Index is : 19
# ...
#
# The Index is : 20
# ...
#
# The Index is : 21
# ...
#
# The Index is : 22
# ...
#
# The Index is : 23
# ...
#
# The Index is : 24
# ...
#
# The Index is : 25
# ...
#
# The Index is : 26
# ...
#
# The Index is : 27
# ...
#
# The Index is : 28
# ...
#
# The Index is : 29
# ...
#
# The Index is : 30
# ...
#
# The Index is : 31
# ...

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
import pandas as pd
pd.read_csv(r"/<fullpath>/supermarket_sales.csv")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\dell pc\Desktop\data\supermarket_sales.csv")
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
data.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                       object
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   object
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200     80.22
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880   489.048
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%    Total        Date   Time  Payment  \
# 995       40.35         1   2.0175  42.3675   1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.49  03-02-2019  17:16  Ewallet
# 997       31.84         1   1.5920   33.432  02-09-2019  13:22     Cash
# 998       65.82         1   3.2910   69.111   2/22/2019  15:33     Cash
# 999       88.34         7  30.9190  649.299   2/18/2019  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
# To calaculate the mean of Gross Income?

data['gross income'].mean()
# Out:
# 15.379369000000002

# %%
data['gross income'].median()
# Out:
# 12.088

# %%
# Mode of gender

data['Gender'].mode()
# Out:
# 0    Female
# dtype: object

# %%
data['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
data['Gender'].nunique()
# Out:
# 2

# %%
data.describe(include='O')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     726-29-6793      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#           Total        Date   Time  Payment
# count      1000        1000   1000     1000
# unique      990          89    506        3
# top     175.917  02-07-2019  14:42  Ewallet
# freq          2          20      7      345

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   307.58738
# std      26.494628     2.923431    11.708825   234.17651
# min      10.080000     1.000000     0.508500    10.17000
# 25%      32.875000     3.000000     5.924875   118.49750
# 50%      55.230000     5.000000    12.088000   241.76000
# 75%      77.935000     8.000000    22.445250   448.90500
# max      99.960000    10.000000    49.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.220360e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# ...

# %%
# ## create a function:
#     #arg: Data
    
#     - shape
#     - dtype
#     - head
#     - tail
#     - Info
#     - describe
#     - null
#     - 
#     - 
#     - 
    
    
def summaryOfData(df):
    shapeOfData= df.shape
    print("The Shape of the input data is :",shapeOfData)

# %%
summaryOfData(data)
# Out:
# The Shape of the input data is : (48842, 15)

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200     80.22
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880   489.048
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
# Total Gross Income?
totalGrossIncome = data['gross income'].sum()
print("Total Gross income is : ",totalGrossIncome)
# Out:
# Total Gross income is :  15379.368999999999

# %%
# which is the most commonly used Payment Type?
payament = data['Payment'].mode()[0]
print("most commonly used Payment Type is :", payament)
print(payament,"most commonly used Payment Type is :",payament,"continue..."  )
# Out:
# most commonly used Payment Type is : Ewallet
# Ewallet most commonly used Payment Type is : Ewallet continue...

# %%
# f - formatted string literal 
# What is the average unit price of the products ?
averageValue = data['Unit price'].mean()
print(f"The average unit price of the products is {averageValue}")
print(f"The average unit price of the products identified is {averageValue} for the XYZ supermarket" )
# Out:
# The average unit price of the products is 55.67212999999998
# The average unit price of the products identified is 55.67212999999998 for the XYZ supermarket

# %%
#what is the standard deviation of product unit price ?
data['Unit price'].std()
# Out:
# 26.494628347919768

# %%
# what is the total number of sales? == number of Invoices?
# data['Invoice ID'].nunique()
# data['Invoice ID'].count()
# data['Invoice ID'].shape[0]
# data['Invoice ID'].size
# Out:
# 1000

# %%
data['Invoice ID'].value_counts()
# Out:
# 726-29-6793    1
# 639-76-1242    1
# 785-13-7708    1
# 253-12-6086    1
# 191-29-0321    1
#               ..
# 578-80-7669    1
# 745-71-3520    1
# 212-62-1842    1
# 272-27-9238    1
# 785-96-0615    1
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
# What are the different types of Product Line ? 
data['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
# Problem 2
data = pd.read_csv("data/adult.csv")

# %%
data.head(100)
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0    25           Private  226802          11th                7
# 1    38           Private   89814       HS-grad                9
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 4    18                 ?  103497  Some-college               10
# 5    34           Private  198693          10th                6
# 6    29                 ?  227026       HS-grad                9
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 8    24           Private  369667  Some-college               10
# 9    55           Private  104996       7th-8th                4
# 10   65           Private  184454       HS-grad                9
# 11   36       Federal-gov  212465     Bachelors               13
# 12   26           Private   82091       HS-grad                9
# ...

# %%
data.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
data.describe(include='O')
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      48842     48842               48842           48842        48842
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15784               22379            6172        19716
#
#          race gender native-country income
# count   48842  48842          48842  48842
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    41762  32650          43832  37155

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data.shape
# Out:
# (48842, 15)

# %%
# Avaerage hour hour per week
data['hours-per-week'].mean()
# Out:
# 40.422382375824085

# %%
# Average hours per week for male and female
data.groupby('gender')['hours-per-week'].mean()
# Out:
# gender
# Female    36.400692
# Male      42.416845
# Name: hours-per-week, dtype: float64

# %%
data = [{'name': 'John Doe', 'age': 37, 'sex': 'M'},
        {'name': 'Lisa Simpson', 'age': 17, 'sex': 'F'},
        {'name': 'Bill Clinton', 'age': 57, 'sex': 'M'}]

# %%
new_dict = {}
for item in data:
    for key, value in item.items():
        if key in new_dict:
            new_dict[key].append(value)
        else:
            new_dict[key] =[]
            new_dict[key].append(value)

# %%
new_dict
# Out:
# {'name': ['John Doe', 'Lisa Simpson', 'Bill Clinton'],
#  'age': [37, 17, 57],
#  'sex': ['M', 'F', 'M']}

# %%
############
# March 31 #
############

# Average hours per week for male and female - 
# With respect to working class and Gender calculate Average hours per week.
# With respect to Gender,working class and Gender calculate Average hours per week.
# With respect to Gender,working class and Gender calculate Average Age and hours per week.
# Write a DataFrame into a file
# Pandas Merging, Joining, and Concatenating
# Pandas - Plotting

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data.describe(include='O')
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      48842     48842               48842           48842        48842
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15784               22379            6172        19716
#
#          race gender native-country income
# count   48842  48842          48842  48842
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    41762  32650          43832  37155

# %%
 # With respect to working class and Gender calculate Average hours per week. # "-#?" 
data['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data['workclass'].nunique()
# Out:
# 9

# %%
data['workclass'].mode()[0]
# Out:
# 'Private'

# %%
data['workclass'].value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
data.groupby(['workclass','gender'])['hours-per-week'].mean()
# Out:
# workclass         gender
# ?                 Female    29.914961
#                   Male      33.388489
# Federal-gov       Female    39.882743
#                   Male      42.265306
# Local-gov         Female    39.014308
#                   Male      42.075080
# Never-worked      Female    23.333333
#                   Male      31.285714
# Private           Female    36.510647
#                   Male      42.229524
# Self-emp-inc      Female    42.398104
#                   Male      49.448113
# Self-emp-not-inc  Female    37.227345
#                   Male      45.789669
# State-gov         Female    36.901704
#                   Male      40.462233
# Without-pay       Female    32.285714
#                   Male      34.785714
# Name: hours-per-week, dtype: float64

# %%
# With respect to Race ,working class and Gender calculate Average hours per week.

# %%
data['race'].value_counts()
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
data['race'].mode()[0]
# Out:
# 'White'

# %%
pd.set_option('display.max_rows',1000)

# %%
# Problem 2
data = pd.read_csv("data/adult.csv")
print(data)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.groupby(['race','workclass','gender'])['hours-per-week'].mean() # Before max display rows
# Out:
# race                workclass         gender
# Amer-Indian-Eskimo  ?                 Female    31.789474
#                                       Male      38.875000
#                     Federal-gov       Female    37.684211
#                                       Male      40.928571
#                     Local-gov         Female    37.516129
#                                       Male      41.000000
#                     Private           Female    37.530000
#                                       Male      42.168539
#                     Self-emp-inc      Female    40.000000
#                                       Male      30.000000
#                     Self-emp-not-inc  Female    35.833333
#                                       Male      44.464286
#                     State-gov         Female    41.555556
#                                       Male      49.500000
# Asian-Pac-Islander  ?                 Female    28.617021
# ...

# %%
data.groupby(['race','workclass','gender'])['hours-per-week'].mean() # After max display rows
# Out:
# race                workclass         gender
# Amer-Indian-Eskimo  ?                 Female    31.789474
#                                       Male      38.875000
#                     Federal-gov       Female    37.684211
#                                       Male      40.928571
#                     Local-gov         Female    37.516129
#                                       Male      41.000000
#                     Private           Female    37.530000
#                                       Male      42.168539
#                     Self-emp-inc      Female    40.000000
#                                       Male      30.000000
#                     Self-emp-not-inc  Female    35.833333
#                                       Male      44.464286
#                     State-gov         Female    41.555556
#                                       Male      49.500000
# Asian-Pac-Islander  ?                 Female    28.617021
# ...

# %%
# With respect to Race ,working class and Gender calculate Average Age and hours per week.

# %%
data.groupby(['race','workclass','gender'])['age','hours-per-week'].mean()
# Out:
# <ipython-input-217-b95dea4bcf5c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['race','workclass','gender'])['age','hours-per-week'].mean()
#                                                   age  hours-per-week
# race               workclass        gender
# Amer-Indian-Eskimo ?                Female  33.684211       31.789474
#                                     Male    49.062500       38.875000
#                    Federal-gov      Female  41.526316       37.684211
#                                     Male    41.714286       40.928571
#                    Local-gov        Female  38.516129       37.516129
#                                     Male    39.029412       41.000000
#                    Private          Female  33.830000       37.530000
#                                     Male    33.926966       42.168539
# ...

# %%
outputDF = data.groupby(['race','workclass','gender'])['age','hours-per-week'].mean()
# Out:
# <ipython-input-218-1a93fabe8fdc>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   outputDF = data.groupby(['race','workclass','gender'])['age','hours-per-week'].mean()

# %%
outputDF
# Out:
#                                                   age  hours-per-week
# race               workclass        gender
# Amer-Indian-Eskimo ?                Female  33.684211       31.789474
#                                     Male    49.062500       38.875000
#                    Federal-gov      Female  41.526316       37.684211
#                                     Male    41.714286       40.928571
#                    Local-gov        Female  38.516129       37.516129
#                                     Male    39.029412       41.000000
#                    Private          Female  33.830000       37.530000
#                                     Male    33.926966       42.168539
#                    Self-emp-inc     Female  46.000000       40.000000
#                                     Male    42.000000       30.000000
#                    Self-emp-not-inc Female  38.833333       35.833333
#                                     Male    42.464286       44.464286
# ...

# %%
type(outputDF)
# Out:
# pandas.core.frame.DataFrame

# %%
# to csv
outputDF.to_csv("sample.csv")

# %%
# to excel
outputDF.to_excel("sample2.xlsx")

# %%
# to excel
outputDF.to_excel(r"C:\Users\dell pc\Desktop\data\sample2.xlsx")

# %%
############
# March 31 #
############

# Average hours per week for male and female - 
# With respect to working class and Gender calculate Average hours per week.
# With respect to Gender,working class and Gender calculate Average hours per week.
# With respect to Gender,working class and Gender calculate Average Age and hours per week.
# Write a DataFrame into a file
# ---------------------------------
# Pandas Merging, Joining, and Concatenating
# Pandas - Plotting

# %%
# Pandas Merging, Joining, and Concatenating

# %%
df_customer =pd.DataFrame({
    'id':[1,2,3,4],
    'name':['Tom', 'Jenny', 'James', 'Dan']
})

df_info = pd.DataFrame({
    'id': [2, 3, 4, 5],
    'age': [31, 20, 40, 70],
    'sex': ['F', 'M', 'M', 'F']
})

# %%
df_customer
# Out:
#    id   name
# 0   1    Tom
# 1   2  Jenny
# 2   3  James
# 3   4    Dan

# %%
df_info
# Out:
#    id  age sex
# 0   2   31   F
# 1   3   20   M
# 2   4   40   M
# 3   5   70   F

# %%
pd.merge(df_customer,df_info)
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M

# %%
# pd.merge(df_customer,df_info)

df_customer.merge(df_info)
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M

# %%
pd.merge(df_customer,df_info,on='id')
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M

# %%
############
# April 2 #
############
# Pandas- Concatenating
# Pandas - Plotting
# Matplotlib 
# Seaborn 
# Creating Virtual ENV

# %%
path="E:\AI\LibrariesForAI\Pandas\data"
inputFileName="supermarket_sales.csv"
pathandFileName=path+"\\"+inputFileName

# %%
path
# Out:
# 'E:\\AI\\LibrariesForAI\\Pandas\\data'

# %%
pathandFileName
# Out:
# 'E:\\AI\\LibrariesForAI\\Pandas\\data\\supermarket_sales.csv'

# %%
import os

extention = os.path.basename(pathandFileName).split(".")[1]
if extention=="csv":
    df = pd.read_csv(pathandFileName)
elif extention=="xlsx":
    df = pd.read_excel(pathandFileName)
elif extention=="json":
    df =pd.read_json(pathandFileName)
else:
    print("No Extention Found!")

# %%
os.pwd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-ccf365d595bf> in <module>
# ----> 1 os.pwd()
#
# AttributeError: module 'os' has no attribute 'pwd'

# %%
# ## create a function:
#     #arg: Data
    
#     - shape
#     - dtypes
#     - head
#     - tail
#     - Info
#     - describe
#     - null
#     - 
#     - 
#     - 
import os
import pandas as pd
path="E:\AI\LibrariesForAI\Pandas\data"
inputFileName="supermarket_sales.csv"

def summaryOfData(path,inputFileName):
    pathandFileName=path+"\\"+inputFileName
    extension = os.path.basename(pathandFileName).split(".")[1]
    if extension =="csv":
        df = pd.read_csv(pathandFileName)
    elif extension =="xlsx":
        df = pd.read_excel(pathandFileName)
    elif extension =="xls":
        df = pd.read_excel(pathandFileName)
    elif extension =="json":
        df = pd.read_json(pathandFileName)
    else:
        print("Extension not found, Please recheck!")
    print("The Name of the Input File : ",inputFileName )
    print("="*60+"\n")
    print("Top 2 rows of the Dataframe :\n\n",df.head(2))
    print("*"*60 +"\n")
    print("Last 2 rows of the Dataframe :\n\n",df.tail(2))
    print("*"*60 +"\n")
    print("The Shape of the input data is :",df.shape)
    print("*"*60 +"\n")
    print("The DataType of the input data is :\n\n",df.dtypes)
    print("*"*60 +"\n")
    print("The Basic Information about the input data is :\n\n")
    print(df.info())
    print("*"*60 +"\n")
    print("Describe the Numerical Dtypes of input data is :\n\n",df.describe())
    print("*"*60 +"\n")
    print("Describe the Categorical Dtypes of input data is :\n\n",df.describe(include="O"))
    print("*"*60 +"\n")
    print("Finding the Null Values if any for the input data :\n\n",df.isnull().sum())
    print("*"*60 +"\n")

# %%
print("="*60,"\n")

# %%
import os
path="E:\AI\LibrariesForAI\Pandas\data"
inputFileName="supermarket_sales.csv"

summaryOfData(path,inputFileName)
# Out:
# The Name of the Input File :  supermarket_sales.csv
# ...
#
# Top 2 rows of the Dataframe :
#
#      Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200     80.22
#
#          Date   Time  Payment    cogs  gross margin percentage  gross income  \
# 0  01-05-2019  13:08  Ewallet  522.83                 4.761905       26.1415
# 1  03-08-2019  10:29     Cash   76.40                 4.761905        3.8200
#
#    Rating
# 0     9.1
# 1     9.6
# ************************************************************
#
# Last 2 rows of the Dataframe :
#
#        Invoice ID Branch    City Customer type  Gender         Product line  \
# ...

# %%
import os
import pandas as pd
path="E:\AI\LibrariesForAI\Pandas\data"
inputFileName="supermarket_sales.csv"
pathandFileName=path+"\\"+inputFileName
extension = os.path.basename(pathandFileName).split(".")[1]
if extension =="csv":
    df = pd.read_csv(pathandFileName)

# %%
os.path.basename(pathandFileName).split(".")
# Out:
# ['supermarket_sales', 'csv']

# %%
extension
# Out:
# '.csv'

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   object
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
import pandas as pd

df= pd.read_csv("data/data.csv")

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
# pip install matplotlib
import matplotlib.pyplot as plt

# %%
df.plot()
plt.show()

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.head().plot(x='Duration',y='Calories',kind="scatter")
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Calories'>

# %%
df.plot(x='Duration',y='Calories',kind="scatter")
plt.show()

# %%
df.plot(x='Duration',y='Maxpulse',kind="scatter")
plt.show()

# %%
df.plot(x='Duration',y='Pulse',kind="scatter")
plt.show()

# %%
df['Duration'].value_counts()
# Out:
# 60     79
# 45     35
# 30     16
# 20      9
# 90      8
# 150     4
# 180     3
# 120     3
# 210     2
# 160     2
# 75      2
# 15      2
# 80      1
# 300     1
# 25      1
# 270     1
# Name: Duration, dtype: int64

# %%
df['Duration'].plot(kind='hist')
plt.show()

# %%
df['Pulse'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Duration'].plot(kind='bar')
# Out:
# <AxesSubplot:>
