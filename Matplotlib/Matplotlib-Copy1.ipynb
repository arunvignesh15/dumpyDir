# %% [markdown]
# #### Matplotlib Pyplot
#
# * What is Matplotlib?
#
#    Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# ### A picture is worth a thousands words
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %% [markdown]
# Where is the Matplotlib Codebase?
#
# The source code for Matplotlib is located at this github repository https://github.com/matplotlib/matplotlib

# %%
# pip install matplotlib

# %% [markdown]
# Pyplot
#
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y)
#plt.plot(x,y,color='green',linewidth=5,linestyle='dotted')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='green',linewidth=5, linestyle='dotted')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
#plt.plot(x,y,'g+')
#plt.plot(x,y,'g+--')
plt.plot(x,y,'b+--')

# %%
plt.plot(x,y,'g+--')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='')

# color can be given hexa decimal value too.

# %%
plt.plot(x,y,color='#888888',marker='D',linestyle='')

# %%
plt.plot(x,y,color='#888888',marker='+',linestyle='', markersize=20)

# %%
plt.plot(x,y,color='green',alpha=0.2)

# %% [markdown]
# #### Axes Labels, Legend, Grid

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
# set axes labels and chart title
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc="best", shadow=True, fontsize="small") # it will smartly move
plt.grid()

# %%
# Normal Dist
# Right Skew
# left Skew
# Uni/BiVariate/Multi
# Pro Density Function


# P Value
# Z score

# %% [markdown]
# #### Bar Chart
#
# This is one of the most common types of visualization that almost everyone must have encountered.
#
# Bars can be drawn horizontally or vertically to represent categorical variables.

# %%
# Simple bar chart showing revenues of major US tech companies

company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,2,34,12]

# %%
plt.xlabel("Major Companies")
plt.ylabel("Revenue")
plt.title("Revenue Model for Top Companies")
plt.bar(company,revenue,label="Revenue")
plt.bar(company,profit,label="Profit")
plt.legend()
plt.show()

# %%
len(company)
# Out:
# 4

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
# Out:
# array([-0.2,  0.8,  1.8,  2.8])

# %%
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
xpos
# Out:
# array([0, 1, 2, 3])

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(xpos,company)
plt.xlabel("Major Companies")
plt.ylabel("Revenue")
plt.title("Revenue Model for Top Companies")
plt.bar(xpos-0.2,revenue,width=0.4,label="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="Profit")
plt.legend()
plt.show()

# %%
plt.xticks(xpos,company)
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.bar(company,revenue,width=0.4,label="Revenue")
plt.bar(company,profit,width=0.4,label="profit")
plt.legend()

# %%
plt.xticks(xpos,company)
plt.xlabel("Company Name")
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.bar(xpos-0.2,revenue,width=0.4,label="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="profit")
plt.legend()

# %%
plt.barh(xpos,revenue, label="Revenue")

plt.yticks(xpos,company)
plt.ylabel("Company Name")
plt.title('US Technolog Stocks')
plt.legend()

# %% [markdown]
# #### Histogram

# %% [markdown]
# In histograms,
# * x axis contains a variable
# * y axis will be a frequency of that variable

# %% [markdown]
# Question :
#
# We have a sample data of blood sugar level of different patients,
#
#  we will try to
#
#     * plot number of patients by blood range
#     * try to figure out how many patients are normal
#     * pre-diabetic and diabetic

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

# %%
plt.hist(blood_sugar)
#plt.show()
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar,rwidth=0.8)

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar, rwidth=0.8) # by default number of bins is set to 10
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
#### bins parameter - # Bins

plt.hist(blood_sugar,bins=3 ,rwidth=0.8,color='green') # by default number of bins is set to 10
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar_men.sort()

# %%
blood_sugar_women
# Out:
# [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("Sugar Level")
plt.ylabel("Number of patients")
plt.title("Charts")
plt.hist([blood_sugar_men,blood_sugar_women],bins=[75,100,125,200],rwidth=0.8,label=['Men','Women'],color=['red','black'])
#plt.legend()
#plt.show()
# Out:
# (array([[7., 2., 4.],
#         [5., 4., 2.]]),
#  array([ 75, 100, 125, 200]),
#  <a list of 2 BarContainer objects>)

# %%
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.8,color='green') # by default number of bins is set to 10

# %%
salary=[10,15,20,30,40,50,60,70,80,90,100]

# %%
plt.hist(blood_sugar,bins=[80,100,125,150] ,rwidth=0.8) # by default number of bins is set to 10
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# Histogram showing normal, pre-diabetic and diabetic patients distribution
#
# * 80-100: Normal
# * 100-125: Pre-diabetic
# * 80-100: Diabetic

# %%
plt.hist(blood_sugar,bins=[80,100,125,150] ,rwidth=0.8,color='g')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# #### Mutiple data samples in a histogram

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")
plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150],rwidth=0.8,color=['green','orange'],label=['men','women'])
plt.legend()

# %%
plt.xlabel("Number Of Patients")
plt.ylabel("Sugar Level")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, orientation='horizontal')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# #### Box Plot using Matplotlib
#
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.
#
# The whiskers go from each quartile to the minimum or maximum.
#
# ![image](https://media.geeksforgeeks.org/wp-content/uploads/20201109141359/BVoxplot.jpg)
#
#
# Numpy.random.normal()  - Array filled with random values as per gaussian distribution
#
# NumPy. random.normal(loc = 0.0, scale = 1.0, size = None)
#
# Parameters:
#
# * loc – This is an optional parameter, which specifies the mean (peak) of distribution. The default value is 0.0.
# * scale – This is an optional parameter, which specifies the standard deviation or how flat the distribution graph should be. The default value is 1.0.
# * size – This is an optional parameter, which specifies the shape of the resultant array. The default value is 1.
# Return value – The return value of this function is the NumPy array of random samples from a normal distribution.

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
np.random.seed(15)
data = np.random.normal(100,20,200)

# %%
data
# Out:
# array([ 93.75343037, 106.78569412,  96.88182932,  89.96420653,
#        104.71137783,  64.72789486,  78.08275912,  78.24468517,
#         93.89659896,  90.52503256,  95.98810923, 107.10393546,
#        113.79035446, 108.21179351,  88.70043125, 111.9878138 ,
#         96.7412739 , 132.00429005, 113.63254409, 100.29760203,
#         98.24440736,  80.35764319, 102.43380957,  77.25125428,
#        106.98005156,  62.82973679,  76.65636228, 128.4979366 ,
#        129.93130725, 125.79864111,  63.76509466,  70.0338558 ,
#         70.99713564,  66.12186077, 104.54528055,  90.20530578,
#         99.98942987,  90.19494766,  84.13581157, 140.97797527,
#        112.06370877,  80.03595844, 124.30083102,  86.64967017,
#         94.54988446, 128.33548962,  84.34782084,  94.99358606,
#         93.83371077, 134.5937606 , 139.56544737, 104.39376064,
#        137.89639699,  72.63801126,  96.17389228, 125.74515067,
#         95.06232112, 106.85102165, 104.45434084, 113.63187411,
# ...

# %%
plt.hist(data,rwidth=0.8)
# Out:
# (array([ 1.,  3.,  6., 16., 35., 51., 45., 18., 17.,  8.]),
#  array([ 30.67480558,  42.49302485,  54.31124412,  66.12946339,
#          77.94768266,  89.76590193, 101.58412121, 113.40234048,
#         125.22055975, 137.03877902, 148.85699829]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(10,5))
plt.boxplot(data)
plt.show()

# %%
np.mean(data)
# Out:
# 99.00187885901765

# %%
np.median(data)
# Out:
# 97.62056331670928

# %%
np.random.seed(10)
data_1 = np.random.normal(100,10,200)
data_2 = np.random.normal(90,20,200)
data_3 = np.random.normal(80,30,200)
data_4 = np.random.normal(70,40,200)

data=[data_1,data_2,data_3,data_4]
plt.figure(figsize=(10,5))

plt.boxplot(data,vert=False,patch_artist=True)
plt.show()

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plot

 
# Creating dataset
np.random.seed(10)
data = np.random.normal(100, 20, 200)
 
fig = plt.figure(figsize =(10, 5))
 
# Creating plot
plt.boxplot(data)
 
# show plot
plt.show()

# %%
np.mean(data)
# Out:
# 101.48613846633367

# %%
np.median(data)
# Out:
# 101.8873682842476

# %%
plot.hist(data)
plot.show()

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np


# Creating dataset
np.random.seed(10)

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize =(10, 7))


# Creating plot
plt.boxplot(data,vert=True,patch_artist=False)

# show plot
plt.show()

# %% [markdown]
# #### Pie Chart
#
# A Pie Chart is a circular statistical plot that can display only one series of data. The area of the chart is the total percentage of the given data. The area of slices of the pie represents the percentage of the parts of the data.
#
# To find out the result in percentage
#
# ![image](pie1.PNG)
# ![image](pie2.PNG)

# %%
# Draw pie chart to track down home expenses
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent- 1400","Food","Phone/Internet Bill","Car ","Other Utilities"]

plt.figure(figsize =(10, 7))
plt.axis('equal')
plt.pie(exp_vals,labels=exp_labels,radius=1.2,autopct="%0.2f%%",shadow=True,explode=[0.1,0,0.2,0,0],startangle=45)
plt.legend()
# plt.show()
plt.savefig("piechart_new.pdf")

# %%
# Draw pie chart to track down home expenses
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

plt.pie(exp_vals,labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d1bbe908b0>,
# ...
#  [Text(0.09328656407206024, 1.0960372333838069, 'Home Rent'),
#   Text(-0.9822184890776084, -0.4952240298229684, 'Food'),
#   Text(-0.16284704617934698, -1.0878790555712807, 'Phone/Internet Bill'),
#   Text(0.6256100334857941, -0.9047718419590123, 'Car '),
#   Text(1.0615045230766318, -0.28845822485734873, 'Other Utilities')])

# %%
# Show percentages for every pie. Specify radius to increase chart size

# %%
plt.axis('equal')
plt.pie(exp_vals,labels=exp_labels,radius=1.5,autopct='%0.2f%%',shadow=True)
plt.show()

# %%
# Explode

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%0.2f%%',radius=1.5,explode=[0.1,0,0.2,0,0]) # [0,0,0,0.1,0.2]
plt.show()

# %%
# angle properties

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2], startangle=180) # startangle=180 - chnag the value
plt.show()

# %% [markdown]
# #### Save the Chart
#
# Saving chart to a file using savefig

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=2, autopct='%0.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig("piechart.jpg", bbox_inches="tight", pad_inches=1, transparent=True)

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=2, autopct='%0.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig(r"C:\Users\dell pc\Desktop\data\piechart.pdf", bbox_inches="tight", pad_inches=1, transparent=True)
